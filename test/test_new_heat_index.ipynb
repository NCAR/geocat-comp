# %%
import sys
sys.path.append("../")
print(sys.path)
# Out:
# ['/Users/anissaz/miniconda3/envs/geocat_comp_build/lib/python313.zip', '/Users/anissaz/miniconda3/envs/geocat_comp_build/lib/python3.13', '/Users/anissaz/miniconda3/envs/geocat_comp_build/lib/python3.13/lib-dynload', '', '/Users/anissaz/miniconda3/envs/geocat_comp_build/lib/python3.13/site-packages', '../']

# %%
from geocat.comp.meteorology import heat_index, new_heat_index
import timeit
import numpy as np
import xarray as xr

# %%
# %load_ext line_profiler
# %load_ext memory_profiler

# %%
shape = (10000, 1000)
rh = np.random.uniform(low=40, high=90, size=shape)
t = np.random.uniform(low=30, high=92, size=shape)

# %%
# %%timeit
heat_index(t, rh)
# Out:
# 553 ms ± 14 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
new_heat_index(t, rh)
# Out:
# 2.83 s ± 13.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %memit heat_index(t, rh)
# Out:
# peak memory: 1327.95 MiB, increment: 28.70 MiB

# %%
# %memit new_heat_index(t, rh)
# Out:
# peak memory: 1111.20 MiB, increment: 89.67 MiB

# %%
# %prun heat_index(t, rh)
# Out:
#          1654 function calls (1645 primitive calls) in 0.565 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.154    0.154    0.368    0.368 meteorology.py:113(_heat_index)
#         1    0.149    0.149    0.149    0.149 meteorology.py:230(_nws_eqn)
#        46    0.147    0.003    0.147    0.003 {built-in method builtins.any}
#         4    0.056    0.014    0.059    0.015 duck_array_ops.py:399(where)
#       3/1    0.035    0.012    0.000    0.000 {method 'control' of 'select.kqueue' objects}
#       5/4    0.012    0.002    0.759    0.190 selectors.py:540(select)
#         2    0.005    0.002    0.005    0.002 {built-in method builtins.abs}
#         4    0.002    0.000    0.002    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         1    0.001    0.001    0.369    0.369 <string>:1(<module>)
# ...

# %%
# %prun new_heat_index(t, rh)
# Out:
#          1248 function calls (1232 primitive calls) in 2.896 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    1.788    1.788    2.826    2.826 meteorology.py:11(new_heat_index)
#         2    0.866    0.433    0.866    0.433 {built-in method numpy.asarray}
#         1    0.123    0.123    0.123    0.123 meteorology.py:230(_nws_eqn)
#       5/1    0.027    0.005    0.000    0.000 {method 'control' of 'select.kqueue' objects}
#         4    0.024    0.006    0.024    0.006 {method 'flatten' of 'numpy.ndarray' objects}
#       5/1    0.024    0.005    0.000    0.000 selectors.py:540(select)
#         2    0.021    0.010    0.021    0.011 duck_array_ops.py:399(where)
#         1    0.019    0.019    2.845    2.845 <string>:1(<module>)
#         2    0.001    0.000    0.001    0.000 {method '__exit__' of 'sqlite3.Connection' objects}
# ...
